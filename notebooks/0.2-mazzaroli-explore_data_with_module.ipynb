# %% [markdown]
# # 0.2 Explore data

# %% [markdown]
# ## Libraries

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import final_project.data.processing as processing
import final_project.utils.paths as path
import final_project.visualization.visualize as visualize
import janitor
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %% [markdown]
# ## Read data

# %%
processed_covid_file = path.data_processed_dir("time_series_covid19_confirmed_global_processed.csv")

# %%
processed_covid_df = pd.read_csv(processed_covid_file)
processed_covid_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 294202 entries, 0 to 294201
# Data columns (total 3 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   country_region  294202 non-null  object
#  1   date            294202 non-null  object
#  2   value           294202 non-null  int64
# dtypes: int64(1), object(2)
# memory usage: 6.7+ MB

# %%
processed_covid_df.head()
# Out:
#   country_region        date  value
# 0    Afghanistan  2020-01-22      0
# 1        Albania  2020-01-22      0
# 2        Algeria  2020-01-22      0
# 3        Andorra  2020-01-22      0
# 4         Angola  2020-01-22      0

# %% [markdown]
# ## Explore data

# %%
sns.set_style("whitegrid")

# %% [markdown]
# ### Appearance of new covid-19 cases in Latam
#
# Subset data.

# %%
countries = ['Argentina', 'Brazil', 'Chile', 'Colombia', 'Mexico', 'Peru']
some_latam_countries_df = processed_covid_df.filter_on(f"country_region in {countries}")
some_latam_countries_df.head(3)
# Out:
#    country_region        date  value
# 7       Argentina  2020-01-22      0
# 31         Brazil  2020-01-22      0
# 58          Chile  2020-01-22      0

# %%
visualize.covid_time_series(some_latam_countries_df)

# %% [markdown]
# ### Latam in global context

# %%
visualize.top_countries(processed_covid_df, 20, countries)
